# %% [markdown]
# <a href="https://colab.research.google.com/github/AljowharaAlblaihed/Chapter-12-assignment-/blob/main/Copy_of_05_Presentation_Layouts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <table style="float:left; border:none">
#    <tr style="border:none">
#        <td style="border:none">
#            <a href="https://bokeh.org/">
#            <img
#                src="https://github.com/daniel-dc-cd/data_science/blob/master/daily_materials/bokeh-notebooks/tutorial/assets/bokeh-transparent.png?raw=1"
#                style="width:50px"
#            >
#            </a>
#        </td>
#        <td style="border:none">
#            <h1>Bokeh Tutorial</h1>
#        </td>
#    </tr>
# </table>
#
# <div style="float:right;"><h2>05. Presentation and Layout</h2></div>

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

output_notebook()

# %% [markdown]
# In the previous chapters we started to learn how to create single plots using differnet kinds of data. But we often want to plot more than one thing. Bokeh plots can be individually embedded in HTML documents, but it's often easier to
# combine multiple plots in one of Bokeh's built-in layouts. We will learn how to do that in this chapter
#
# The cell below defines a few data variables we will use in examples.

# %%
x = list(range(11))
y0, y1, y2= x, [10-i for i in x], [abs(i-5) for i in x]

# %% [markdown]
# # Rows and Columns
# The `bokeh.layouts` modules provides the ``row`` and ``column`` functions to arrange plot objects in vertical or horizontal layouts. Below is an example of three plots arranged in a row.

# %%
from bokeh.layouts import row

# create a new plot
s1 = figure(width=250, plot_height=250)
s1.circle(x, y0, size=10, color="navy", alpha=0.5)

# create another one
s2 = figure(width=250, height=250)
s2.triangle(x, y1, size=10, color="firebrick", alpha=0.5)

# create and another
s3 = figure(width=250, height=250)
s3.square(x, y2, size=10, color="olive", alpha=0.5)

# show the results in a row
show(row(s1, s2, s3))
# Out:
#   <div class="bk-root" id="13fc1cda-9bed-4629-8098-01ebda080c07" data-root-id="31456"></div>

# %%
# EXERCISE: use column to arrange a few plots vertically (don't forget to import column)
from bokeh.io import output_file, show
from bokeh.layouts import column #import column
from bokeh.plotting import figure

output_file("layout.html")
#defined before
#x = list(range(11))
#y0 = x
#y1 = [10 - i for i in x]
#y2 = [abs(i - 5) for i in x]

# create three plots
s1 = figure(plot_width=250, plot_height=250, background_fill_color="#f9f9f9") #defined width, height and background color for s1 plot * I know the backgroun not required but it's more details just *
s1.circle(x, y0, size=10, color="navy", alpha=0.5) #the shape is circle and color is navy

s2 = figure(plot_width=250, plot_height=250, background_fill_color="#f9f9f9") #defined width, height and background color for s2 plot
s2.triangle(x, y1, size=10, color="firebrick", alpha=0.5) #the shape is triangle and color is firebrick

s3 = figure(plot_width=250, plot_height=250, background_fill_color="#f9f9f9") #defined width, height and background color for s3 plot
s3.square(x, y2, size=10, color="olive", alpha=0.5) #the shape is square and color is olive

# put the results in a column and show
show(column(s1, s2, s3))
# Out:
#   <div class="bk-root" id="29f19dcc-b447-47c4-99b8-4eccd6b6d52b" data-root-id="32727"></div>

# %% [markdown]
# # Grid plots
#
# Bokeh also provides a `gridplot` layout in `bokeh.layouts` for arranging plots in a grid, as show in the example below.

# %%
from bokeh.layouts import gridplot

# create a new plot
s1 = figure(width=250, plot_height=250)
s1.circle(x, y0, size=10, color="navy", alpha=0.5)

# create another one
s2 = figure(width=250, height=250)
s2.triangle(x, y1, size=10, color="firebrick", alpha=0.5)

# create and another
s3 = figure(width=250, height=250)
s3.square(x, y2, size=10, color="olive", alpha=0.5)

# put all the plots in a gridplot
p = gridplot([[s1, s2], [s3, None]], toolbar_location=None)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="b6ae0398-0bf2-4794-b8c8-ff791ba8f877" data-root-id="6806"></div>

# %%
# EXERCISE: create a gridplot of your own
from bokeh.layouts import gridplot

# create a new plot
s1 = figure(width=250, plot_height=250)
s1.circle(x, y0, size=10, color="navy", alpha=0.5)

# create another one
s2 = figure(width=250, height=250)
s2.triangle(x, y1, size=10, color="firebrick", alpha=0.5)

# create and another
s3 = figure(width=250, height=250)
s3.square(x, y2, size=10, color="olive", alpha=0.5)


# put all the plots in a gridplot
p = gridplot([[s1, None], [s3, s2]], toolbar_location=None)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="a1e53d43-d0a9-4872-86be-ae78e1e9082d" data-root-id="15825"></div>

# %% [markdown]
# # Next Section

# %% [markdown]
# Click on this link to go to the next notebook: [06 - Linking and Interactions](06%20-%20Linking%20and%20Interactions.ipynb).
#
# To go back to the overview, click [here](00%20-%20Introduction%20and%20Setup.ipynb).

# %% [markdown]
# ## Bouns

# %%
import pandas as pd
pd.read_parquet('https://github.com/gumdropsteve/datasets/raw/master/airlines.parquet')
# Out:
#          ArrDelayBinary  t_Year  t_Month  ...   Dest  Distance  Diverted
# 0                     0  1991.0      8.0  ...  244.0     110.0       0.0
# 1                     0  1990.0     11.0  ...   11.0     595.0       0.0
# 2                     0  1991.0      1.0  ...  175.0     412.0       0.0
# 3                     0  1991.0      6.0  ...   11.0     545.0       0.0
# 4                     0  1988.0     10.0  ...  171.0     866.0       0.0
# ...                 ...     ...      ...  ...    ...       ...       ...
# 3999995               0  1987.0     10.0  ...  150.0     332.0       0.0
# 3999996               0  1990.0      7.0  ...   22.0     321.0       0.0
# 3999997               0  1987.0     11.0  ...    8.0     108.0       0.0
# 3999998               0  1991.0      8.0  ...  149.0     395.0       0.0
# 3999999               0  1990.0      7.0  ...   96.0     288.0       0.0
#
# [4000000 rows x 14 columns]

# %% [markdown]
# ### Level 1 Bonus: Create a line chart to compare AAPL and TSLA stock data.

# %%
# create a new plot with a title and axis labels
p = figure(title="Adjusted Closing Price Compairson ($)", 
           x_axis_label='Date', 
           y_axis_label='Adj Close ($)',
           x_axis_type='datetime')

tsla = pd.read_csv('https://raw.githubusercontent.com/gumdropsteve/datasets/master/stocks/TSLA.csv')
aapl = pd.read_csv('https://raw.githubusercontent.com/gumdropsteve/datasets/master/stocks/AAPL.csv')


# add a line renderer with legend and line thickness
p.line(x=pd.to_datetime(tsla['ds']), y=tsla['adj_close'], legend_label="TSLA", line_width=2)
p.line(x=pd.to_datetime(aapl['Date']), y=aapl['Adj Close'], legend_label="AAPL", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="5cb428f6-58e5-4792-9e82-63bdd1a0828e" data-root-id="14753"></div>

# %% [markdown]
# ### Level 2 Bonus: Create the same line, scatter, and bar plots you created yesterday, but with Bokeh. Titanic dataset or dataset of your choosing.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/gumdropsteve/intro_to_python/main/day_09/data/titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %% [markdown]
# ### Level 2 Bonus: Create the same line, scatter, and bar plots you created yesterday, but with Bokeh. Titanic dataset or dataset of your choosing.

# %%
from bokeh.plotting import figure, output_file, show

# output to static HTML file
output_file("line.html")

p = figure(plot_width=400, plot_height=400)

# add a circle renderer with a size, color, and alpha
p.circle(x=df['Fare'], y=df['Age'], size=15, color="navy", alpha=0.5)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="911cdcf8-2bb2-4354-8043-8c9c806c8d0c" data-root-id="27890"></div>
